# %%
import json
metrics =  open("output/Caltech_Pedestrians_run1/metrics.json").read().splitlines()

# %%
for line in metrics:
    line_d = json.loads(line)
    if "bbox/AP" in line_d.keys(): print(line_d)
# Out:
# {'bbox/AP': 20.769612274603972, 'bbox/AP-_background': nan, 'bbox/AP-pedestrian': 20.769612274603972, 'bbox/AP50': 47.67672108445829, 'bbox/AP75': 15.219514500213672, 'bbox/APl': 44.48697215820297, 'bbox/APm': 30.562837591890112, 'bbox/APs': 12.054728599509284, 'data_time': 0.007720000925473869, 'eta_seconds': 88125.28801121516, 'fast_rcnn/cls_accuracy': 0.9833984375, 'fast_rcnn/false_negative': 0.39165996245642265, 'fast_rcnn/fg_cls_accuracy': 0.6083400375435773, 'iteration': 4999, 'loss_box_reg': 0.07147166691720486, 'loss_cls': 0.04803680349141359, 'loss_rpn_cls': 0.008643280365504324, 'loss_rpn_loc': 0.008174969465471804, 'lr': 0.001, 'rank_data_time': 0.005959168425761163, 'roi_head/num_bg_samples': 496.5, 'roi_head/num_fg_samples': 15.5, 'rpn/num_neg_anchors': 252.5, 'rpn/num_pos_anchors': 3.5, 'time': 1.181338407448493, 'total_loss': 0.1339791954960674}
# ...
